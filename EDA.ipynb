# %%
import pandas as pd

df = pd.read_csv('LengthOfStay.csv')

# %%
len(df)
# Out:
# 100000

# %%
df.head()
# Out:
#    eid       vdate rcount gender  dialysisrenalendstage  asthma  irondef  \
# 0    1   8/29/2012      0      F                      0       0        0
# 1    2   5/26/2012     5+      F                      0       0        0
# 2    3   9/22/2012      1      F                      0       0        0
# 3    4    8/9/2012      0      F                      0       0        0
# 4    5  12/20/2012      0      F                      0       0        0
#
#    pneum  substancedependence  psychologicaldisordermajor  ...     glucose  \
# 0      0                    0                           0  ...  192.476918
# 1      0                    0                           0  ...   94.078507
# 2      0                    0                           0  ...  130.530524
# 3      0                    0                           0  ...  163.377028
# 4      1                    0                           1  ...   94.886654
#
#    bloodureanitro  creatinine        bmi  pulse  respiration  \
# ...

# %%
df.describe()
# Out:
#                  eid  dialysisrenalendstage         asthma        irondef  \
# count  100000.000000          100000.000000  100000.000000  100000.000000
# mean    50000.500000               0.036420       0.035270       0.094940
# std     28867.657797               0.187334       0.184462       0.293134
# min         1.000000               0.000000       0.000000       0.000000
# 25%     25000.750000               0.000000       0.000000       0.000000
# 50%     50000.500000               0.000000       0.000000       0.000000
# 75%     75000.250000               0.000000       0.000000       0.000000
# max    100000.000000               1.000000       1.000000       1.000000
#
#                pneum  substancedependence  psychologicaldisordermajor  \
# count  100000.000000        100000.000000               100000.000000
# mean        0.039450             0.063060                    0.239040
# std         0.194664             0.243072                    0.426499
# ...

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# eid                           0
# vdate                         0
# rcount                        0
# gender                        0
# dialysisrenalendstage         0
# asthma                        0
# irondef                       0
# pneum                         0
# substancedependence           0
# psychologicaldisordermajor    0
# depress                       0
# psychother                    0
# fibrosisandother              0
# malnutrition                  0
# hemo                          0
# hematocrit                    0
# neutrophils                   0
# sodium                        0
# glucose                       0
# bloodureanitro                0
# creatinine                    0
# bmi                           0
# pulse                         0
# respiration                   0
# secondarydiagnosisnonicd9     0
# discharged                    0
# facid                         0
# lengthofstay                  0
# dtype: int64

# %% [markdown]
# No Missing or Null Values

# %% [markdown]
# ### Checking Data Types

# %%
df.dtypes
# Out:
# eid                             int64
# vdate                          object
# rcount                         object
# gender                         object
# dialysisrenalendstage           int64
# asthma                          int64
# irondef                         int64
# pneum                           int64
# substancedependence             int64
# psychologicaldisordermajor      int64
# depress                         int64
# psychother                      int64
# fibrosisandother                int64
# malnutrition                    int64
# hemo                            int64
# hematocrit                    float64
# neutrophils                   float64
# sodium                        float64
# glucose                       float64
# bloodureanitro                float64
# creatinine                    float64
# bmi                           float64
# pulse                           int64
# respiration                   float64
# secondarydiagnosisnonicd9       int64
# ...

# %% [markdown]
# ### Converting Dates

# %%
df['vdate'] = pd.to_datetime(df['vdate'])
df['discharged'] = pd.to_datetime(df['discharged'])

# %% [markdown]
# ### Understanding Categorical Variables

# %%
df['gender'].value_counts()
# Out:
# gender
# F    57643
# M    42357
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='gender', data=df)
plt.show()

# %%
sns.countplot(x='rcount', data=df)

for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# We can see that 55031 admission have no readmission count.

# %% [markdown]
# ### Numercial Variables

# %%
df['lengthofstay'].hist(bins=20)
plt.show()

# %% [markdown]
# This binned graph shows the no of patients in that stayed in the hospital for respective days.

# %%
sns.boxplot(x='lengthofstay', data=df)
plt.show()

# %% [markdown]
# ## Understanding distribution of Stay Periods

# %%
sns.histplot(df['lengthofstay'], kde=True)
plt.show()

# %%
sns.scatterplot(x='pulse', y='lengthofstay', data=df)
plt.show()

# %%
sns.pairplot(df[['lengthofstay', 'rcount', 'pulse']])
plt.show()
# Out:
# C:\Users\srila\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['rcount'] = label_encoder.fit_transform(df['rcount'])
df['gender'] = label_encoder.fit_transform(df['gender'])
df['facid'] = label_encoder.fit_transform(df['facid'])

# %%
corr_matrix = df.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(16, 14))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns

# Calculate the correlation matrix for 'lengthofstay' and other numerical features
correlation_matrix_lengthofstay = df[numerical_features].corr()['lengthofstay'].sort_values(ascending=False)

# Plotting the correlation values as a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_matrix_lengthofstay.index, y=correlation_matrix_lengthofstay.values, palette='coolwarm')
plt.title('Correlation with Length of Stay')
plt.xticks(rotation=45)
plt.show()
